# %%
! pip install pymongo
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient('mongodb+srv://Rathnamari:Rathnamari@cluster0.oe3fdas.mongodb.net/?retryWrites=true&w=majority')
db = client['sample_airbnb']
col = db['listingsAndReviews']

# %%
list = []
for i in col.find():
  list.append(i)

df = pd.DataFrame(list)
df.head(1)
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name  \
# 0  Horto flat with small garden
#
#                                              summary  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                                space  \
# 0  Lovely one bedroom + sofa-bed in the living ro...
#
#                                          description  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                neighborhood_overview  \
# 0  This charming ground floor flat is located in ...
#
#                                                notes  \
# 0  There´s a table in the living room now, that d...
#
#                                              transit access  ...  \
# 0  Easy access to transport (bus, taxi, car) and ...         ...
#
#                                               images  \
# ...

# %%
data = []
for i in col.find({},{'_id':1,'listing_url':1,'name':1,'property_type':1,'room_type':1,'bed_type':1,
                        'minimum_nights':1,'maximum_nights':1,'cancellation_policy':1,'accommodates':1,
                        'bedrooms':1,'beds':1,'number_of_reviews':1,'bathrooms':1,'price':1,'amenities':1,
                        'cleaning_fee':1,'extra_people':1,'guests_included':1,'images.picture_url':1,
                        'review_scores.review_scores_rating':1}):
  data.append(i)

df1 = pd.DataFrame(data)

df1['images'] = df1['images'].apply(lambda x:x['picture_url'])
df1['review_scores'] = df1['review_scores'].apply(lambda x:x.get('review_scores_rating',0))

df1.head(1)
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name property_type        room_type  bed_type  \
# 0  Horto flat with small garden     Apartment  Entire home/apt  Real Bed
#
#   minimum_nights maximum_nights cancellation_policy  accommodates  ...  beds  \
# 0              2           1125            flexible             4  ...   2.0
#
#    number_of_reviews  bathrooms  \
# 0                  0        1.0
#
#                                            amenities   price cleaning_fee  \
# 0  [Wifi, Wheelchair accessible, Kitchen, Free pa...  317.00       187.00
#
#   extra_people guests_included  \
# 0         0.00               1
#
#                                               images review_scores
# 0  https://a0.muscache.com/im/pictures/5b408b9e-4...             0
#
# [1 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   property_type        5555 non-null   object
#  4   room_type            5555 non-null   object
#  5   bed_type             5555 non-null   object
#  6   minimum_nights       5555 non-null   object
#  7   maximum_nights       5555 non-null   object
#  8   cancellation_policy  5555 non-null   object
#  9   accommodates         5555 non-null   int64
#  10  bedrooms             5550 non-null   float64
#  11  beds                 5542 non-null   float64
#  12  number_of_reviews    5555 non-null   int64
#  13  bathrooms            5545 non-null   object
#  14  amenities            5555 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# amenities                 0
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# dtype: int64

# %%
df1['bedrooms'].fillna(0,inplace = True)
df1['beds'].fillna(0,inplace = True)
df1['bathrooms'].fillna(0,inplace = True)
df1['cleaning_fee'].fillna('Not Specified',inplace = True)

df1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# amenities              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   property_type        5555 non-null   object
#  4   room_type            5555 non-null   object
#  5   bed_type             5555 non-null   object
#  6   minimum_nights       5555 non-null   object
#  7   maximum_nights       5555 non-null   object
#  8   cancellation_policy  5555 non-null   object
#  9   accommodates         5555 non-null   int64
#  10  bedrooms             5555 non-null   float64
#  11  beds                 5555 non-null   float64
#  12  number_of_reviews    5555 non-null   int64
#  13  bathrooms            5555 non-null   object
#  14  amenities            5555 non-null   object
# ...

# %%
df1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# amenities               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df1.minimum_nights = df1['minimum_nights'].astype(int)
df1.maximum_nights = df1['maximum_nights'].astype(int)
df1.bedrooms = df1['bedrooms'].astype(float)
df1.beds = df1['beds'].astype(float)
df1.bathrooms = df1['bathrooms'].astype(str).astype(float)
df1.price = df1['price'].astype(str).astype(float).astype(int)
df1.cleaning_fee = df1['cleaning_fee'].apply(lambda x: int(float(str(x))) if x !='Not Specified' else 'Not Specified')
df1.extra_people = df1['extra_people'].astype(str).astype(float).astype(int)
df1.guests_included = df1['guests_included'].astype(str).astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   property_type        5555 non-null   object
#  4   room_type            5555 non-null   object
#  5   bed_type             5555 non-null   object
#  6   minimum_nights       5555 non-null   int32
#  7   maximum_nights       5555 non-null   int32
#  8   cancellation_policy  5555 non-null   object
#  9   accommodates         5555 non-null   int64
#  10  bedrooms             5555 non-null   float64
#  11  beds                 5555 non-null   float64
#  12  number_of_reviews    5555 non-null   int64
#  13  bathrooms            5555 non-null   float64
#  14  amenities            5555 non-null   object
# ...

# %%
df1.describe().T
# Out:
#                     count          mean           std  min   25%     50%  \
# minimum_nights     5555.0  5.564356e+00  2.261386e+01  1.0   1.0     2.0
# maximum_nights     5555.0  1.382776e+06  5.256920e+07  1.0  59.0  1125.0
# accommodates       5555.0  3.505851e+00  2.297019e+00  1.0   2.0     3.0
# bedrooms           5555.0  1.410441e+00  1.042334e+00  0.0   1.0     1.0
# beds               5555.0  2.066607e+00  1.620858e+00  0.0   1.0     2.0
# number_of_reviews  5555.0  2.760648e+01  4.979838e+01  0.0   1.0     5.0
# bathrooms          5555.0  1.288839e+00  7.037643e-01  0.0   1.0     1.0
# price              5555.0  2.787662e+02  8.422155e+02  9.0  70.0   129.0
# extra_people       5555.0  2.279190e+01  6.933151e+01  0.0   0.0     0.0
# guests_included    5555.0  1.747435e+00  1.487352e+00  1.0   1.0     1.0
# review_scores      5555.0  6.839568e+01  4.182983e+01  0.0   0.0    92.0
#
#                       75%           max
# minimum_nights        3.0  1.250000e+03
# ...

# %%
host = []
for i in col.find({},{'_id':1,'host':1}):
    host.append(i)
df_host = pd.DataFrame(host)    
host_keys = df_host.iloc[0,1].keys()


for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x:x[i] if i in x else 'Not Specified')


df_host.drop('host_about',axis = 1, inplace = True)
df_host.drop('host_url',axis = 1, inplace = True)
df_host.drop('host_thumbnail_url',axis = 1, inplace = True)
df_host.drop('host_picture_url',axis = 1, inplace = True)
df_host.drop('host', axis = 1, inplace = True)
df_host
# Out:
#            _id   host_id       host_name  \
# 0     10009999   1282196           Ynaie
# 1      1001265   5448114           David
# 2     10057447  51612949      Konstantin
# 3     10057826  47554473             Mae
# 4     10059244   7140229            Caro
# ...        ...       ...             ...
# 5550   9944044  51104303  Sara And Scott
# 5551   9951865  51142039         Dailton
# 5552   9979991  51283546          Alexis
# 5553   9987200  51314789          Dumont
# 5554   9993190  51013381  Coconut Condos
#
#                                         host_location host_neighbourhood  \
# 0     Rio de Janeiro, State of Rio de Janeiro, Brazil    Jardim Botânico
# 1                     Honolulu, Hawaii, United States            Waikiki
# 2                            Montreal, Quebec, Canada           Mile End
# 3                                                  US         Greenpoint
# 4                            Montreal, Quebec, Canada
# ...

# %%
address = []
for i in col.find({},{'_id':1, 'address':1}):
    address.append(i)

df_address = pd.DataFrame(address)

address_keys = df_address.iloc[0,1].keys()

for i in address_keys:
   
    if i =='location':
        df_address['longitude'] = df_address['address'].apply(lambda x : x['location']['coordinates'][0])
        df_address['latitude'] = df_address['address'].apply(lambda x : x['location']['coordinates'][1])
    else:
         df_address[i] = df_address['address'].apply(lambda x : x[i] if i in x else 'Not Specified')      
        
df_address.drop('address', axis=1, inplace = True)

df_address
# Out:
#            _id                                           street  \
# 0     10009999           Rio de Janeiro, Rio de Janeiro, Brazil
# 1      1001265                      Honolulu, HI, United States
# 2     10057447                         Montréal, Québec, Canada
# 3     10057826                      Brooklyn, NY, United States
# 4     10059244                         Montréal, Québec, Canada
# ...        ...                                              ...
# 5550   9944044                         Bundeena, NSW, Australia
# 5551   9951865  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 5552   9979991                    Hong Kong, Kowloon, Hong Kong
# 5553   9987200           Rio de Janeiro, Rio de Janeiro, Brazil
# 5554   9993190                       Lahaina, HI, United States
#
#                      suburb                government_area          market  \
# 0           Jardim Botânico                Jardim Botânico  Rio De Janeiro
# ...

# %%
availability = []
for i in col.find({},{'_id':1,'availability':1}):
    availability.append(i)
    
df_availability = pd.DataFrame(availability)

availability_keys = df_availability.iloc[0,1].keys()

for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x : x ['availability_30'] if i in x else 'Not Specified')
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x : x ['availability_60'] if i in x else 'Not Specified')
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x : x ['availability_90'] if i in x else 'Not Specified')
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x : x ['availability_365'] if i in x else 'Not Specified')

df_availability.drop('availability',axis = 1, inplace = True)
df_availability
# Out:
#            _id  availability_30  availability_60  availability_90  \
# 0     10009999                0                0                0
# 1      1001265               16               46               76
# 2     10057447                0                0                0
# 3     10057826               30               31               31
# 4     10059244                0                0                0
# ...        ...              ...              ...              ...
# 5550   9944044               30               60               90
# 5551   9951865               30               60               90
# 5552   9979991                0                0                0
# 5553   9987200                7               29               53
# 5554   9993190                0                8               31
#
#       availability_365
# 0                    0
# 1                  343
# 2                    0
# 3                  243
# 4                   32
# ...                ...
# ...

# %%
df1 = pd.merge(df1,df_host , on = '_id')
df1 = pd.merge(df1,df_address , on = '_id')
df1 = pd.merge(df1,df_availability , on = '_id')
df1.head(2)
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1   1001265   https://www.airbnb.com/rooms/1001265
#
#                                name property_type        room_type  bed_type  \
# 0      Horto flat with small garden     Apartment  Entire home/apt  Real Bed
# 1  Ocean View Waikiki Marina w/prkg   Condominium  Entire home/apt  Real Bed
#
#    minimum_nights  maximum_nights          cancellation_policy  accommodates  \
# 0               2            1125                     flexible             4
# 1               3             365  strict_14_with_grace_period             2
#
#    ...       government_area          market        country  country_code  \
# 0  ...       Jardim Botânico  Rio De Janeiro         Brazil            BR
# 1  ...  Primary Urban Center            Oahu  United States            US
#
#    longitude   latitude availability_30  availability_60  availability_90  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        5555 non-null   object
#  1   listing_url                5555 non-null   object
#  2   name                       5555 non-null   object
#  3   property_type              5555 non-null   object
#  4   room_type                  5555 non-null   object
#  5   bed_type                   5555 non-null   object
#  6   minimum_nights             5555 non-null   int32
#  7   maximum_nights             5555 non-null   int32
#  8   cancellation_policy        5555 non-null   object
#  9   accommodates               5555 non-null   int64
#  10  bedrooms                   5555 non-null   float64
#  11  beds                       5555 non-null   float64
#  12  number_of_reviews          5555 non-null   int64
# ...

# %%
df1.to_csv('airbnb.csv')
